# %%
import pandas as pd
from pathlib import Path

# %%
crime_data = Path("/Users/hazelmena/Desktop/Homework/project-1/Violence_Reduction_-_Victims_of_Homicides_and_Non-Fatal_Shootings.csv")

# %%
df = pd.read_csv(crime_data)

# %%
df.head()
# Out:
#   CASE_NUMBER                    DATE               BLOCK  \
# 0    JF167335  03/08/2022 03:27:00 PM  6000 N KENMORE AVE
# 1    JB114490  01/13/2018 01:25:00 AM      900 W 114TH PL
# 2    HP340136  05/16/2008 11:46:00 PM   9200 S RACINE AVE
# 3    JF293080  06/25/2022 12:41:00 AM      2100 W 36TH ST
# 4    JG150300  02/12/2023 05:57:00 PM       400 E 83RD ST
#
#   VICTIMIZATION_PRIMARY INCIDENT_PRIMARY GUNSHOT_INJURY_I          UNIQUE_ID  \
# 0              HOMICIDE         HOMICIDE               NO    HOM-JF167335-#1
# 1               BATTERY          BATTERY              YES  SHOOT-JB114490-#1
# 2              HOMICIDE         HOMICIDE              YES    HOM-HP340136-#1
# 3              HOMICIDE         HOMICIDE              YES    HOM-JF293080-#1
# 4              HOMICIDE         HOMICIDE              YES    HOM-JG150300-#1
#
#    ZIP_CODE  WARD      COMMUNITY_AREA  ... MONTH  DAY_OF_WEEK  HOUR  \
# 0   60660.0  48.0           EDGEWATER  ...     3            3    15
# ...

# %%
del df['UPDATED']
del df['LONGITUDE']
del df['LATITUDE']
del df['LOCATION']
del df['STATE_HOUSE_DISTRICT']
del df['STATE_SENATE_DISTRICT']
del df['HOMICIDE_VICTIM_FIRST_NAME']
del df['HOMICIDE_VICTIM_MI']
del df['HOMICIDE_VICTIM_LAST_NAME']
del df['ZIP_CODE']
del df['BLOCK']
del df['UNIQUE_ID']
del df['WARD']
del df['INCIDENT_IUCR_SECONDARY']
del df['VICTIMIZATION_FBI_DESCR']
del df['INCIDENT_FBI_DESCR']
del df['VICTIMIZATION_FBI_CD']
del df['INCIDENT_FBI_CD']
del df['VICTIMIZATION_IUCR_CD']
del df['INCIDENT_IUCR_CD']
       
df.head()
# Out:
#   CASE_NUMBER                    DATE VICTIMIZATION_PRIMARY INCIDENT_PRIMARY  \
# 0    JF167335  03/08/2022 03:27:00 PM              HOMICIDE         HOMICIDE
# 1    JB114490  01/13/2018 01:25:00 AM               BATTERY          BATTERY
# 2    HP340136  05/16/2008 11:46:00 PM              HOMICIDE         HOMICIDE
# 3    JF293080  06/25/2022 12:41:00 AM              HOMICIDE         HOMICIDE
# 4    JG150300  02/12/2023 05:57:00 PM              HOMICIDE         HOMICIDE
#
#   GUNSHOT_INJURY_I      COMMUNITY_AREA STREET_OUTREACH_ORGANIZATION  AREA  \
# 0               NO           EDGEWATER                          NaN   3.0
# 1              YES         MORGAN PARK                          NaN   2.0
# 2              YES  WASHINGTON HEIGHTS  Acclivus Washington Heights   2.0
# 3              YES       MCKINLEY PARK       Envision McKinley Park   1.0
# 4              YES             CHATHAM                          NaN   2.0
#
# ...

# %%
df.count()
# Out:
# CASE_NUMBER                     56703
# DATE                            56703
# VICTIMIZATION_PRIMARY           56703
# INCIDENT_PRIMARY                56703
# GUNSHOT_INJURY_I                56703
# COMMUNITY_AREA                  56698
# STREET_OUTREACH_ORGANIZATION    41552
# AREA                            56698
# DISTRICT                        56698
# BEAT                            56698
# AGE                             56703
# SEX                             56703
# RACE                            56703
# VICTIMIZATION_IUCR_SECONDARY    48298
# MONTH                           56703
# DAY_OF_WEEK                     56703
# HOUR                            56703
# LOCATION_DESCRIPTION            56703
# dtype: int64

# %%
df = df.dropna(how='any')

# %%
df.count()
# Out:
# CASE_NUMBER                     35768
# DATE                            35768
# VICTIMIZATION_PRIMARY           35768
# INCIDENT_PRIMARY                35768
# GUNSHOT_INJURY_I                35768
# COMMUNITY_AREA                  35768
# STREET_OUTREACH_ORGANIZATION    35768
# AREA                            35768
# DISTRICT                        35768
# BEAT                            35768
# AGE                             35768
# SEX                             35768
# RACE                            35768
# VICTIMIZATION_IUCR_SECONDARY    35768
# MONTH                           35768
# DAY_OF_WEEK                     35768
# HOUR                            35768
# LOCATION_DESCRIPTION            35768
# dtype: int64

# %%
df.to_csv("/Users/hazelmena/Desktop/Homework/project-1/Violence_Reduction_-_Victims_of_Homicides_and_Non-Fatal_Shootings.csv", index=False)
