# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path

# %%
crime_data = Path("/Users/hazelmena/Desktop/Homework/project-1/Violence_Reduction_-_Victims_of_Homicides_and_Non-Fatal_Shootings.csv")
crime_data_df = pd.read_csv("/Users/hazelmena/Desktop/Homework/project-1/Violence_Reduction_-_Victims_of_Homicides_and_Non-Fatal_Shootings.csv")
df = pd.read_csv(crime_data)
df.head()
# Out:
#   CASE_NUMBER     DATE VICTIMIZATION_PRIMARY INCIDENT_PRIMARY  \
# 0    HP340136  5/16/08              HOMICIDE         HOMICIDE
# 1    JF293080  6/25/22              HOMICIDE         HOMICIDE
# 2    JG147400  2/10/23              HOMICIDE         HOMICIDE
# 3    JG214225   4/7/23              HOMICIDE         HOMICIDE
# 4    JC293192   6/5/19               BATTERY          BATTERY
#
#   GUNSHOT_INJURY_I      COMMUNITY_AREA           STREET_OUTREACH_ORGANIZATION  \
# 0              YES  WASHINGTON HEIGHTS            Acclivus Washington Heights
# 1              YES       MCKINLEY PARK                 Envision McKinley Park
# 2              YES         SOUTH SHORE       Claretian Associates South Shore
# 3              YES  WEST GARFIELD PARK  READI 60624 | INVC West Garfield Park
# 4              YES        CHICAGO LAWN                      SWOP Chicago Lawn
#
#    AREA  DISTRICT  BEAT    AGE SEX RACE VICTIMIZATION_IUCR_SECONDARY  MONTH  \
# ...

# %%
x_axis = np.arange(len(crime_data_df))
tick_locations = [value+0.4 for value in x_axis]
